# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravlochab/dailoGPT/blob/main/dialoGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installations
# %%capture
# !pip install transformers==3.0.2

# %%
import pandas as pd

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer 
import torch 
tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium") 
model = AutoModelWithLMHead.from_pretrained("microsoft/DialoGPT-medium") 
for step in range(3): 
    new_user_input_ids = tokenizer.encode(input(">> User:") + tokenizer.eos_token, return_tensors='pt')  
    bot_input_ids = torch.cat([gen_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids  
    gen_ids = model.generate(bot_input_ids, max_length=200, pad_token_id=tokenizer.eos_token_id)  
    print("DialoGPT: {}".format(tokenizer.decode(gen_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_auto.py:798: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# WARNING:transformers.modeling_utils:Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at microsoft/DialoGPT-medium and are newly initialized: ['transformer.h.0.attn.masked_bias', 'transformer.h.1.attn.masked_bias', 'transformer.h.2.attn.masked_bias', 'transformer.h.3.attn.masked_bias', 'transformer.h.4.attn.masked_bias', 'transformer.h.5.attn.masked_bias', 'transformer.h.6.attn.masked_bias', 'transformer.h.7.attn.masked_bias', 'transformer.h.8.attn.masked_bias', 'transformer.h.9.attn.masked_bias', 'transformer.h.10.attn.masked_bias', 'transformer.h.11.attn.masked_bias', 'transformer.h.12.attn.masked_bias', 'transformer.h.13.attn.masked_bias', 'transformer.h.14.attn.masked_bias', 'transformer.h.15.attn.masked_bias', 'transformer.h.16.attn.masked_bias', 'transformer.h.17.attn.masked_bias', 'transformer.h.18.attn.masked_bias', 'transformer.h.19.attn.masked_bias', 'transformer.h.20.attn.masked_bias', 'transformer.h.21.attn.masked_bias', 'transformer.h.22.attn.masked_bias', 'transformer.h.23.attn.masked_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# >> User:hi
# DialoGPT: Hey! :D
# >> User:i love you
# DialoGPT: I love you too! :D
# >> User:eat poop
# DialoGPT: I love you too! :D

# %%
# !unzip /content/drive/MyDrive/DialoGPT/counselchat-convai.zip
# Out:
# Archive:  /content/drive/MyDrive/DialoGPT/counselchat-convai.zip
#    creating: counselchat-convai/
#   inflating: counselchat-convai/added_tokens.json
#   inflating: counselchat-convai/events.out.tfevents.1586138049.3b21657f0ca9
#   inflating: counselchat-convai/tokenizer_config.json
#   inflating: counselchat-convai/special_tokens_map.json
#   inflating: counselchat-convai/config.json
#   inflating: counselchat-convai/model_training_args.bin
#   inflating: counselchat-convai/merges.txt
#   inflating: counselchat-convai/pytorch_model.bin
#   inflating: counselchat-convai/vocab.json

# %%
df = pd.read_csv("/content/counselchat-data.csv", encoding='utf-8')
df.head()
# Out:
#                  questionID  \
# 0  573a0c74dc68e0c40704b147
# 1  573a0c74dc68e0c40704b147
# 2  573a0c74dc68e0c40704b147
# 3  56dcf60656eceaa34f948f94
# 4  56b30469c2bfe0f729d6e74e
#
#                                        questionTitle  \
# 0  How do I help my husband get over his drinking...
# 1  How do I help my husband get over his drinking...
# 2  How do I help my husband get over his drinking...
# 3  Why does it feel as if self-harm is an addiction?
# 4         My husband was lying about drinking again.
#
#                                         questionText  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  I self-harm, and I stop for awhile. Then when ...
# 4  My husband has had issues with alcohol addicti...
#
#                                          questionUrl  \
# 0  https://counselchat.com/questions/how-do-i-hel...
# 1  https://counselchat.com/questions/how-do-i-hel...
# 2  https://counselchat.com/questions/how-do-i-hel...
# 3  https://counselchat.com/questions/why-does-it-...
# 4  https://counselchat.com/questions/my-husband-w...
#
#                            topics  \
# 0                       Addiction
# 1                       Addiction
# 2                       Addiction
# 3  Addiction,Depression,Self-harm
# 4     Addiction,Marriage,Intimacy
#
#                                        therapistName  \
# 0                                  Sherry Katz, LCSW
# 1                       Karen Keys, LMHC, CASAC, NCC
# 2  2nd Chance Counseling Service  Online Addictio...
# 3                          Todd Schmenk, M.S., M.Ed.
# 4                                      Lynda Martens
#
#                                         therapistUrl  \
# 0  https://counselchat.com/therapists/sherry-katz...
# 1  https://counselchat.com/therapists/karen-keys-...
# 2  https://counselchat.com/therapists/2nd-chance-...
# 3  https://counselchat.com/therapists/todd-schmen...
# 4  https://counselchat.com/therapists/ms-lynda-ma...
#
#                                           answerText  upvotes Unnamed: 9  \
# 0  <p>By being truthful with him about how his dr...      0.0  Addiction
# 1  <div>It's not easy to be married to an alcohol...      0.0  Addiction
# 2  <p>Acknowledgment from your husband and wiling...      0.0  Addiction
# 3  <p>In a way, self-harm can present somewhat li...      0.0  Addiction
# 4  <p>Hi Los Angeles,</p><p>So your husband is gi...      0.0  Addiction
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14  \
# 0         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN
# 3  Depression   Self-harm         NaN         NaN          NaN
# 4    Marriage    Intimacy         NaN         NaN          NaN
#
#                                          Unnamed: 15  \
# 0  By being truthful with him about how his drink...
# 1  It's not easy to be married to an alcoholic an...
# 2  Acknowledgment from your husband and wiling to...
# 3  In a way,  self-harm can present somewhat like...
# 4  Hi Los Angeles, So your husband is giving you ...
#
#                                          Unnamed: 16  \
# 0  By being honest with him about how his alcohol...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Unnamed: 17  \
# 0  By honest about how his alcohol consumption af...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Unnamed: 18
# 0  With honesty about drinking his alcohol affect...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# !git clone https://github.com/nbertagnolli/counsel-chat.git
# Out:
# Cloning into 'counsel-chat'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 35 (delta 11), reused 25 (delta 4), pack-reused 0
# Unpacking objects: 100% (35/35), done.
